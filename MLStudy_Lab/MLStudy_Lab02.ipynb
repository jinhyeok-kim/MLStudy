# %% [markdown]
# # ML Lab02 : TensorFlow로 간단한 linear regression 구현
#
# ## Hypothesis and cost function
#
# $$H(x) = Wx + b $$
# $$cost(W,b) = \frac{1}{m}\sum_{i=1}^m (H(x_i)-y_i)^2 $$
#
# cost function의 결과 값이 가장 작은 값이 되도록 W,b를 구해야한다.
#
# ### 1. Build graph using TF operations

# %%
import tensorflow as tf
# X and Y data
x_train = [1, 2, 3]
y_train = [1, 2, 3]

# Variable이라는 Node
# 기존의 변수와는 조금 다른 개념
# Tensorflow가 사용하는 variable 또 다른 말로는 trainable variable이라고 한다.
# tf.random_normal([1]) 여기서 [1]은 값이 하나인 1차원 array. rank가 1.
W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

# Wx + b
hypothesis = x_train * W + b

# cost/Loss function
# tf.reduce_mean()이라는 함수는 tensor가 주어줬을 때 평균을 내주는 함수
# t = [1., 2., 3., 4.]
# tf.reduce_mean(t) ==> 2.5
cost = tf.reduce_mean(tf.square(hypothesis - y_train))

# cost를 minmize해줘야한다. 이때 tensorflow에서 쓰는 방법중에 하나는
# GradientDescent를 사용하는 것이다.

# Minmize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
#train은 그래프의 이름이 될 것이다.
train = optimizer.minimize(cost)


sess = tf.Session()
# 우리는 W,b라는 tensorflow를 사용했고, tensorflow에서 변수를 사용하기 위해서는
# tf.global_variables_initializer()를 실행해야한다.
sess.run(tf.global_variables_initializer())

# sess.run(train)을 2000번 정도 step을 돌 것이고
for step in range(2001):
    sess.run(train)
    
    # step이 20번 돌 때마다 출력을 하라
    if step % 20 == 0:
        print(step, sess.run(cost), sess.run(W), sess.run(b))
# Out:
# (0, 0.8835327, array([1.3799015], dtype=float32), array([-1.6471113], dtype=float32))
# (20, 0.3060555, array([1.6097605], dtype=float32), array([-1.4607337], dtype=float32))
# (40, 0.27346393, array([1.6046908], dtype=float32), array([-1.3817085], dtype=float32))
# (60, 0.24832338, array([1.5785186], dtype=float32), array([-1.3157853], dtype=float32))
# (80, 0.22553106, array([1.5515443], dtype=float32), array([-1.2538543], dtype=float32))
# (100, 0.20483094, array([1.5256443], dtype=float32), array([-1.1949189], dtype=float32))
# (120, 0.18603076, array([1.500943], dtype=float32), array([-1.1387615], dtype=float32))
# (140, 0.16895615, array([1.4774005], dtype=float32), array([-1.0852438], dtype=float32))
# (160, 0.15344863, array([1.4549645], dtype=float32), array([-1.0342412], dtype=float32))
# (180, 0.13936456, array([1.4335828], dtype=float32), array([-0.9856358], dtype=float32))
# (200, 0.12657316, array([1.4132061], dtype=float32), array([-0.93931466], dtype=float32))
# (220, 0.11495576, array([1.393787], dtype=float32), array([-0.8951702], dtype=float32))
# (240, 0.10440465, array([1.3752804], dtype=float32), array([-0.85310054], dtype=float32))
# (260, 0.094822, array([1.3576436], dtype=float32), array([-0.81300795], dtype=float32))
# (280, 0.086118795, array([1.3408355], dtype=float32), array([-0.77479947], dtype=float32))
# (300, 0.07821444, array([1.3248174], dtype=float32), array([-0.7383866], dtype=float32))
# (320, 0.07103562, array([1.3095523], dtype=float32), array([-0.70368505], dtype=float32))
# (340, 0.06451571, array([1.2950045], dtype=float32), array([-0.67061454], dtype=float32))
# (360, 0.058594164, array([1.2811403], dtype=float32), array([-0.639098], dtype=float32))
# (380, 0.05321616, array([1.2679278], dtype=float32), array([-0.6090627], dtype=float32))
# (400, 0.048331756, array([1.2553362], dtype=float32), array([-0.5804391], dtype=float32))
# (420, 0.04389569, array([1.2433362], dtype=float32), array([-0.55316067], dtype=float32))
# (440, 0.03986678, array([1.2319005], dtype=float32), array([-0.52716416], dtype=float32))
# (460, 0.03620766, array([1.2210021], dtype=float32), array([-0.50238943], dtype=float32))
# (480, 0.0328844, array([1.2106158], dtype=float32), array([-0.47877905], dtype=float32))
# (500, 0.029866124, array([1.2007176], dtype=float32), array([-0.4562782], dtype=float32))
# (520, 0.02712488, array([1.1912845], dtype=float32), array([-0.43483478], dtype=float32))
# (540, 0.02463524, array([1.1822947], dtype=float32), array([-0.41439912], dtype=float32))
# (560, 0.022374144, array([1.1737276], dtype=float32), array([-0.3949239], dtype=float32))
# (580, 0.020320551, array([1.1655631], dtype=float32), array([-0.37636396], dtype=float32))
# (600, 0.01845545, array([1.1577822], dtype=float32), array([-0.35867605], dtype=float32))
# (620, 0.016761515, array([1.1503669], dtype=float32), array([-0.3418195], dtype=float32))
# (640, 0.01522307, array([1.1433], dtype=float32), array([-0.3257552], dtype=float32))
# (660, 0.013825811, array([1.1365656], dtype=float32), array([-0.31044576], dtype=float32))
# (680, 0.012556831, array([1.1301475], dtype=float32), array([-0.29585597], dtype=float32))
# (700, 0.011404316, array([1.1240312], dtype=float32), array([-0.2819518], dtype=float32))
# (720, 0.010357588, array([1.1182021], dtype=float32), array([-0.26870117], dtype=float32))
# (740, 0.009406918, array([1.1126469], dtype=float32), array([-0.2560732], dtype=float32))
# (760, 0.008543521, array([1.1073531], dtype=float32), array([-0.2440387], dtype=float32))
# (780, 0.007759362, array([1.102308], dtype=float32), array([-0.23256981], dtype=float32))
# (800, 0.0070471764, array([1.0974997], dtype=float32), array([-0.22163993], dtype=float32))
# (820, 0.006400364, array([1.0929177], dtype=float32), array([-0.21122366], dtype=float32))
# (840, 0.005812907, array([1.0885509], dtype=float32), array([-0.20129697], dtype=float32))
# (860, 0.005279386, array([1.0843893], dtype=float32), array([-0.19183677], dtype=float32))
# (880, 0.004794814, array([1.0804232], dtype=float32), array([-0.18282121], dtype=float32))
# (900, 0.0043547284, array([1.0766437], dtype=float32), array([-0.17422926], dtype=float32))
# (920, 0.003955035, array([1.0730418], dtype=float32), array([-0.1660411], dtype=float32))
# (940, 0.0035920215, array([1.069609], dtype=float32), array([-0.15823781], dtype=float32))
# (960, 0.0032623417, array([1.0663377], dtype=float32), array([-0.15080118], dtype=float32))
# (980, 0.0029629113, array([1.0632201], dtype=float32), array([-0.14371412], dtype=float32))
# (1000, 0.0026909492, array([1.0602487], dtype=float32), array([-0.13695997], dtype=float32))
# (1020, 0.0024439676, array([1.0574174], dtype=float32), array([-0.13052326], dtype=float32))
# (1040, 0.002219647, array([1.054719], dtype=float32), array([-0.12438911], dtype=float32))
# (1060, 0.0020159164, array([1.0521474], dtype=float32), array([-0.11854327], dtype=float32))
# (1080, 0.0018308886, array([1.0496966], dtype=float32), array([-0.11297217], dtype=float32))
# (1100, 0.0016628451, array([1.0473611], dtype=float32), array([-0.10766291], dtype=float32))
# (1120, 0.0015102215, array([1.0451354], dtype=float32), array([-0.1026032], dtype=float32))
# (1140, 0.001371614, array([1.0430142], dtype=float32), array([-0.09778126], dtype=float32))
# (1160, 0.001245719, array([1.0409925], dtype=float32), array([-0.09318594], dtype=float32))
# (1180, 0.0011313794, array([1.039066], dtype=float32), array([-0.08880639], dtype=float32))
# (1200, 0.0010275347, array([1.0372301], dtype=float32), array([-0.08463278], dtype=float32))
# (1220, 0.0009332259, array([1.0354805], dtype=float32), array([-0.08065537], dtype=float32))
# (1240, 0.0008475669, array([1.033813], dtype=float32), array([-0.07686485], dtype=float32))
# (1260, 0.00076977746, array([1.0322239], dtype=float32), array([-0.07325251], dtype=float32))
# (1280, 0.00069912366, array([1.0307096], dtype=float32), array([-0.06980997], dtype=float32))
# (1300, 0.0006349519, array([1.0292662], dtype=float32), array([-0.06652916], dtype=float32))
# (1320, 0.00057667965, array([1.0278908], dtype=float32), array([-0.06340253], dtype=float32))
# (1340, 0.00052374654, array([1.0265801], dtype=float32), array([-0.06042285], dtype=float32))
# (1360, 0.0004756778, array([1.025331], dtype=float32), array([-0.05758318], dtype=float32))
# (1380, 0.000432017, array([1.0241405], dtype=float32), array([-0.05487699], dtype=float32))
# (1400, 0.00039236597, array([1.0230061], dtype=float32), array([-0.05229801], dtype=float32))
# (1420, 0.00035635402, array([1.021925], dtype=float32), array([-0.04984026], dtype=float32))
# (1440, 0.0003236479, array([1.0208946], dtype=float32), array([-0.04749801], dtype=float32))
# (1460, 0.0002939419, array([1.0199125], dtype=float32), array([-0.04526591], dtype=float32))
# (1480, 0.00026695943, array([1.0189766], dtype=float32), array([-0.04313846], dtype=float32))
# (1500, 0.00024245812, array([1.0180848], dtype=float32), array([-0.04111103], dtype=float32))
# (1520, 0.0002202053, array([1.0172349], dtype=float32), array([-0.03917893], dtype=float32))
# (1540, 0.00019999337, array([1.0164249], dtype=float32), array([-0.03733766], dtype=float32))
# (1560, 0.00018163519, array([1.015653], dtype=float32), array([-0.03558295], dtype=float32))
# (1580, 0.00016496476, array([1.0149174], dtype=float32), array([-0.03391068], dtype=float32))
# (1600, 0.00014982333, array([1.0142163], dtype=float32), array([-0.03231698], dtype=float32))
# (1620, 0.00013607224, array([1.0135481], dtype=float32), array([-0.03079818], dtype=float32))
# (1640, 0.00012358175, array([1.0129113], dtype=float32), array([-0.02935072], dtype=float32))
# (1660, 0.00011223941, array([1.0123045], dtype=float32), array([-0.02797131], dtype=float32))
# (1680, 0.00010193684, array([1.0117264], dtype=float32), array([-0.02665677], dtype=float32))
# (1700, 9.2582464e-05, array([1.0111753], dtype=float32), array([-0.02540403], dtype=float32))
# (1720, 8.4083986e-05, array([1.0106502], dtype=float32), array([-0.02421013], dtype=float32))
# (1740, 7.6366974e-05, array([1.0101495], dtype=float32), array([-0.02307235], dtype=float32))
# (1760, 6.935649e-05, array([1.0096725], dtype=float32), array([-0.02198796], dtype=float32))
# (1780, 6.2990555e-05, array([1.009218], dtype=float32), array([-0.02095458], dtype=float32))
# (1800, 5.720998e-05, array([1.0087848], dtype=float32), array([-0.01996981], dtype=float32))
# (1820, 5.1959407e-05, array([1.008372], dtype=float32), array([-0.01903132], dtype=float32))
# (1840, 4.7190522e-05, array([1.0079786], dtype=float32), array([-0.01813696], dtype=float32))
# (1860, 4.285792e-05, array([1.0076035], dtype=float32), array([-0.0172846], dtype=float32))
# (1880, 3.89252e-05, array([1.0072463], dtype=float32), array([-0.01647232], dtype=float32))
# (1900, 3.535316e-05, array([1.0069057], dtype=float32), array([-0.01569824], dtype=float32))
# (1920, 3.210704e-05, array([1.0065811], dtype=float32), array([-0.01496044], dtype=float32))
# (1940, 2.9160472e-05, array([1.0062718], dtype=float32), array([-0.01425735], dtype=float32))
# (1960, 2.648477e-05, array([1.0059772], dtype=float32), array([-0.01358735], dtype=float32))
# (1980, 2.4053288e-05, array([1.0056962], dtype=float32), array([-0.01294878], dtype=float32))
# (2000, 2.1845777e-05, array([1.0054284], dtype=float32), array([-0.01234023], dtype=float32))

# %% [markdown]
# ## Placeholders
#
# 우리가 직접 그 값을 주지 않고, 그 값을 placeholder라는 이름을 주고
# 필요 할 때 값을 던져 준다.

# %%
import tensorflow as tf
# X and Y data
W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

X = tf.placeholder(tf.float32, shape=[None])
Y = tf.placeholder(tf.float32, shape=[None])

# Wx + b
hypothesis = X * W + b

cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minmize
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)


sess = tf.Session()
sess.run(tf.global_variables_initializer())


for step in range(2001):
    cost_val, W_val, b_val, _ = sess.run([cost, W, b, train],
                                        feed_dict={X: [1, 2, 3, 4, 5],
                                                  Y: [2.1, 3.1, 4.1, 5.1, 6.1]})
    if step % 20 == 0:
        print(step, cost_val, W_val, b_val)
# Out:
# (0, 1.7194917, array([1.5546955], dtype=float32), array([0.12136886], dtype=float32))
# (20, 0.1770086, array([1.2733887], dtype=float32), array([0.11760484], dtype=float32))
# (40, 0.15455587, array([1.2543777], dtype=float32), array([0.18163626], dtype=float32))
# (60, 0.13497475, array([1.2377133], dtype=float32), array([0.24177927], dtype=float32))
# (80, 0.11787455, array([1.2221453], dtype=float32), array([0.2979848], dtype=float32))
# (100, 0.10294062, array([1.2075968], dtype=float32), array([0.35050946], dtype=float32))
# (120, 0.08989887, array([1.1940012], dtype=float32), array([0.39959413], dtype=float32))
# (140, 0.078509346, array([1.181296], dtype=float32), array([0.4454642], dtype=float32))
# (160, 0.068562806, array([1.1694227], dtype=float32), array([0.48833022], dtype=float32))
# (180, 0.059876412, array([1.1583271], dtype=float32), array([0.5283889], dtype=float32))
# (200, 0.05229051, array([1.147958], dtype=float32), array([0.5658242], dtype=float32))
# (220, 0.04566572, array([1.1382682], dtype=float32), array([0.6008078], dtype=float32))
# (240, 0.03988021, array([1.129213], dtype=float32), array([0.6335003], dtype=float32))
# (260, 0.03482769, array([1.1207507], dtype=float32), array([0.6640518], dtype=float32))
# (280, 0.03041527, array([1.1128427], dtype=float32), array([0.6926023], dtype=float32))
# (300, 0.026561871, array([1.1054525], dtype=float32), array([0.7192831], dtype=float32))
# (320, 0.02319673, array([1.0985464], dtype=float32), array([0.74421644], dtype=float32))
# (340, 0.020257862, array([1.0920924], dtype=float32), array([0.767517], dtype=float32))
# (360, 0.017691359, array([1.0860612], dtype=float32), array([0.7892915], dtype=float32))
# (380, 0.015450001, array([1.080425], dtype=float32), array([0.8096399], dtype=float32))
# (400, 0.013492611, array([1.075158], dtype=float32), array([0.8286558], dtype=float32))
# (420, 0.011783196, array([1.0702357], dtype=float32), array([0.84642637], dtype=float32))
# (440, 0.010290341, array([1.0656359], dtype=float32), array([0.86303324], dtype=float32))
# (460, 0.008986611, array([1.0613374], dtype=float32), array([0.8785525], dtype=float32))
# (480, 0.007848062, array([1.0573204], dtype=float32), array([0.8930553], dtype=float32))
# (500, 0.0068537733, array([1.0535665], dtype=float32), array([0.9066082], dtype=float32))
# (520, 0.0059854575, array([1.0500582], dtype=float32), array([0.9192736], dtype=float32))
# (540, 0.005227164, array([1.04678], dtype=float32), array([0.9311095], dtype=float32))
# (560, 0.004564909, array([1.0437163], dtype=float32), array([0.9421702], dtype=float32))
# (580, 0.003986573, array([1.0408533], dtype=float32), array([0.95250654], dtype=float32))
# (600, 0.0034815054, array([1.0381777], dtype=float32), array([0.962166], dtype=float32))
# (620, 0.0030404318, array([1.0356774], dtype=float32), array([0.9711928], dtype=float32))
# (640, 0.0026552228, array([1.0333409], dtype=float32), array([0.97962844], dtype=float32))
# (660, 0.002318826, array([1.0311574], dtype=float32), array([0.98751175], dtype=float32))
# (680, 0.0020250478, array([1.0291169], dtype=float32), array([0.9948787], dtype=float32))
# (700, 0.0017684854, array([1.02721], dtype=float32), array([1.0017633], dtype=float32))
# (720, 0.0015444325, array([1.0254279], dtype=float32), array([1.0081967], dtype=float32))
# (740, 0.0013487688, array([1.0237627], dtype=float32), array([1.014209], dtype=float32))
# (760, 0.0011778886, array([1.0222065], dtype=float32), array([1.0198274], dtype=float32))
# (780, 0.0010286614, array([1.0207521], dtype=float32), array([1.025078], dtype=float32))
# (800, 0.0008983343, array([1.0193931], dtype=float32), array([1.0299846], dtype=float32))
# (820, 0.0007845261, array([1.018123], dtype=float32), array([1.03457], dtype=float32))
# (840, 0.0006851315, array([1.0169361], dtype=float32), array([1.0388552], dtype=float32))
# (860, 0.00059832743, array([1.015827], dtype=float32), array([1.0428596], dtype=float32))
# (880, 0.0005225257, array([1.0147904], dtype=float32), array([1.0466019], dtype=float32))
# (900, 0.0004563293, array([1.0138218], dtype=float32), array([1.0500988], dtype=float32))
# (920, 0.00039851022, array([1.0129166], dtype=float32), array([1.0533669], dtype=float32))
# (940, 0.00034802273, array([1.0120707], dtype=float32), array([1.056421], dtype=float32))
# (960, 0.00030392787, array([1.0112802], dtype=float32), array([1.0592753], dtype=float32))
# (980, 0.00026542495, array([1.0105414], dtype=float32), array([1.0619422], dtype=float32))
# (1000, 0.00023180261, array([1.0098511], dtype=float32), array([1.0644344], dtype=float32))
# (1020, 0.00020243603, array([1.0092058], dtype=float32), array([1.0667635], dtype=float32))
# (1040, 0.00017678706, array([1.008603], dtype=float32), array([1.0689402], dtype=float32))
# (1060, 0.00015438977, array([1.0080396], dtype=float32), array([1.0709742], dtype=float32))
# (1080, 0.00013482977, array([1.007513], dtype=float32), array([1.0728751], dtype=float32))
# (1100, 0.00011774794, array([1.007021], dtype=float32), array([1.0746516], dtype=float32))
# (1120, 0.0001028297, array([1.0065612], dtype=float32), array([1.0763117], dtype=float32))
# (1140, 8.980023e-05, array([1.0061315], dtype=float32), array([1.0778631], dtype=float32))
# (1160, 7.842339e-05, array([1.00573], dtype=float32), array([1.079313], dtype=float32))
# (1180, 6.848717e-05, array([1.0053548], dtype=float32), array([1.080668], dtype=float32))
# (1200, 5.981072e-05, array([1.005004], dtype=float32), array([1.081934], dtype=float32))
# (1220, 5.2233343e-05, array([1.0046763], dtype=float32), array([1.083117], dtype=float32))
# (1240, 4.5616405e-05, array([1.0043701], dtype=float32), array([1.0842227], dtype=float32))
# (1260, 3.9837956e-05, array([1.004084], dtype=float32), array([1.0852557], dtype=float32))
# (1280, 3.4791294e-05, array([1.0038165], dtype=float32), array([1.0862212], dtype=float32))
# (1300, 3.0384326e-05, array([1.0035665], dtype=float32), array([1.0871235], dtype=float32))
# (1320, 2.653416e-05, array([1.003333], dtype=float32), array([1.0879668], dtype=float32))
# (1340, 2.3172175e-05, array([1.0031147], dtype=float32), array([1.0887549], dtype=float32))
# (1360, 2.0237141e-05, array([1.0029107], dtype=float32), array([1.0894912], dtype=float32))
# (1380, 1.76746e-05, array([1.0027201], dtype=float32), array([1.0901792], dtype=float32))
# (1400, 1.543416e-05, array([1.002542], dtype=float32), array([1.0908226], dtype=float32))
# (1420, 1.347875e-05, array([1.0023755], dtype=float32), array([1.0914236], dtype=float32))
# (1440, 1.1771827e-05, array([1.00222], dtype=float32), array([1.0919852], dtype=float32))
# (1460, 1.0280345e-05, array([1.0020747], dtype=float32), array([1.09251], dtype=float32))
# (1480, 8.9785135e-06, array([1.0019388], dtype=float32), array([1.0930005], dtype=float32))
# (1500, 7.840372e-06, array([1.0018117], dtype=float32), array([1.0934589], dtype=float32))
# (1520, 6.847382e-06, array([1.0016931], dtype=float32), array([1.0938873], dtype=float32))
# (1540, 5.9802014e-06, array([1.0015823], dtype=float32), array([1.0942876], dtype=float32))
# (1560, 5.223009e-06, array([1.0014787], dtype=float32), array([1.0946615], dtype=float32))
# (1580, 4.5613656e-06, array([1.001382], dtype=float32), array([1.0950108], dtype=float32))
# (1600, 3.983414e-06, array([1.0012914], dtype=float32), array([1.0953376], dtype=float32))
# (1620, 3.4789132e-06, array([1.0012069], dtype=float32), array([1.0956428], dtype=float32))
# (1640, 3.038724e-06, array([1.001128], dtype=float32), array([1.0959281], dtype=float32))
# (1660, 2.6533726e-06, array([1.001054], dtype=float32), array([1.0961946], dtype=float32))
# (1680, 2.3172522e-06, array([1.000985], dtype=float32), array([1.0964439], dtype=float32))
# (1700, 2.0238672e-06, array([1.0009205], dtype=float32), array([1.0966768], dtype=float32))
# (1720, 1.7674265e-06, array([1.0008602], dtype=float32), array([1.0968944], dtype=float32))
# (1740, 1.5438375e-06, array([1.000804], dtype=float32), array([1.0970976], dtype=float32))
# (1760, 1.3481573e-06, array([1.0007514], dtype=float32), array([1.0972875], dtype=float32))
# (1780, 1.1773803e-06, array([1.0007021], dtype=float32), array([1.0974652], dtype=float32))
# (1800, 1.028378e-06, array([1.0006561], dtype=float32), array([1.0976311], dtype=float32))
# (1820, 8.9806855e-07, array([1.0006132], dtype=float32), array([1.0977861], dtype=float32))
# (1840, 7.8456833e-07, array([1.0005732], dtype=float32), array([1.0979309], dtype=float32))
# (1860, 6.8521376e-07, array([1.0005356], dtype=float32), array([1.0980663], dtype=float32))
# (1880, 5.9834736e-07, array([1.0005006], dtype=float32), array([1.0981929], dtype=float32))
# (1900, 5.2263147e-07, array([1.0004678], dtype=float32), array([1.0983112], dtype=float32))
# (1920, 4.563596e-07, array([1.0004371], dtype=float32), array([1.0984218], dtype=float32))
# (1940, 3.9865782e-07, array([1.0004085], dtype=float32), array([1.0985249], dtype=float32))
# (1960, 3.4832578e-07, array([1.000382], dtype=float32), array([1.0986215], dtype=float32))
# (1980, 3.0408208e-07, array([1.0003569], dtype=float32), array([1.0987118], dtype=float32))
# (2000, 2.655946e-07, array([1.0003334], dtype=float32), array([1.0987961], dtype=float32))

# %%
#Testing our model
print(sess.run(hypothesis, feed_dict={X: [5]}))
print(sess.run(hypothesis, feed_dict={X: [2.5]}))
print(sess.run(hypothesis, feed_dict={X: [1.5, 3.5]}))
# Out:
# [6.100463]
# [3.5996296]
# [2.5992963 4.599963 ]

# %% [markdown]
# ---
#
# ## 총 정리
#
# 1. Graph를 TensorFlow 툴을 통해서 빌드한다.
#     - TensorFlow를 통해 hypothesis와 cost에 해당하는 그래프를 만듦
#
#
# $$H(x) = Wx + b $$
# $$cost(W,b) = \frac{1}{m}\sum_{i=1}^m (H(x_i)-y_i)^2 $$
#
# 2. sess.run(op)을 통해서 Graph를 실행시킨다
#     - sess.run(op, feed_dict={x: x_data})
#     - feed_dict를 통해 학습 x y data를 주면서 그래프를 실행
#     <br><br>
# 3. 그 결과로 Graph 속의 어떤 값들이 업데이트되거나 리턴한다.
#     - 내부적으로 W와 b 값을 업데이트 시켰고, 원할 때 hypothesis와 같은 값을 return했다.
